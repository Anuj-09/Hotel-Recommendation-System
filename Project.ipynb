# %% [markdown]
# Hotel Recommendation System

# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from matplotlib import pyplot
import seaborn as sns
# %matplotlib inline

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %% [markdown]
# Fetching Data

# %%
hotel_details=pd.read_csv("D:\HRS Project\Hotel_details.csv" ,delimiter=',')
hotel_rooms=pd.read_csv("D:\HRS Project\Hotel_Room_attributes.csv" ,delimiter=',')

# %%
hotel_details.head()
# Out:
#       id  hotelid                 hotelname                 address     city  \
# 0  46406  1771651  Mediteran Bungalow Galeb            Vukovarska 7     Omis
# 1  46407   177167             Hotel Polonia        Plac Teatralny 5    Torun
# 2  46408  1771675         Rifugio Sass Bece  Belvedere del Pordoi,1  Canazei
# 3  46409   177168            Madalena Hotel                 Mykonos  Mykonos
# 4  46410  1771718         Pension Morenfeld  Mair im Korn Strasse 2  Lagundo
#
#    country  zipcode   propertytype  starrating   latitude  longitude  Source  \
# 0  Croatia  21310.0  Holiday parks           4  43.440124  16.682505       2
# 1   Poland      NaN         Hotels           3  53.012329  18.603800       5
# 2    Italy  38032.0         Hotels           3  46.477920  11.813350       2
# 3   Greece  84600.0         Hotels           3  37.452316  25.329849       5
# 4    Italy  39022.0         Hotels           3  46.682780  11.131736       2
#
#                                                  url curr
# 0  https://www.booking.com/hotel/hr/bungalow-luxu...  EUR
# 1  https://www.agoda.com/en-gb/hotel-polonia/hote...  EUR
# 2  http://www.booking.com/hotel/it/rifugio-sass-b...  EUR
# 3  https://www.agoda.com/en-gb/madalena-hotel/hot...  EUR
# 4  http://www.booking.com/hotel/it/pension-morenf...  EUR

# %%
hotel_rooms.head()
# Out:
#          id  hotelcode                                      roomamenities  \
# 0  50677497     634876  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 1  50672149    8328096  Air conditioning: ;Closet: ;Fireplace: ;Free W...
# 2  50643430    8323442  Air conditioning: ;Closet: ;Dishwasher: ;Firep...
# 3  50650317       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
# 4  50650318       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
#
#                roomtype                                    ratedescription  \
# 0           Double Room       Room size: 15 m²/161 ft², Shower, 1 king bed
# 1         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 2         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 3  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds
# 4  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds
#
#    guest no  price
# 0         6    199
# 1         6    309
# 2         2    398
# 3         4    122
# 4         1    189

# %%
hotel_rooms.rename(columns={'guest no':'guests_no'},inplace=True)

# %%
hotel_rooms.head()
# Out:
#          id  hotelcode                                      roomamenities  \
# 0  50677497     634876  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 1  50672149    8328096  Air conditioning: ;Closet: ;Fireplace: ;Free W...
# 2  50643430    8323442  Air conditioning: ;Closet: ;Dishwasher: ;Firep...
# 3  50650317       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
# 4  50650318       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
#
#                roomtype                                    ratedescription  \
# 0           Double Room       Room size: 15 m²/161 ft², Shower, 1 king bed
# 1         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 2         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 3  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds
# 4  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds
#
#    guests_no  price
# 0          6    199
# 1          6    309
# 2          2    398
# 3          4    122
# 4          1    189

# %% [markdown]
# Data Exploration
#
# 1) General Exploring
#
# 2) Statistical Analysis
#
# 3) Issues
#
# Analysis of both numerical and data value

# %%
hotel_details.columns
# Out:
# Index(['id', 'hotelid', 'hotelname', 'address', 'city', 'country', 'zipcode',
#        'propertytype', 'starrating', 'latitude', 'longitude', 'Source', 'url',
#        'curr'],
#       dtype='object')

# %%
hotel_rooms.columns
# Out:
# Index(['id', 'hotelcode', 'roomamenities', 'roomtype', 'ratedescription',
#        'guests_no', 'price'],
#       dtype='object')

# %% [markdown]
# Numerical observatons

# %%
hotel_rooms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165873 entries, 0 to 165872
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165873 non-null  int64
#  1   hotelcode        165873 non-null  int64
#  2   roomamenities    161054 non-null  object
#  3   roomtype         165873 non-null  object
#  4   ratedescription  161054 non-null  object
#  5   guests_no        165873 non-null  int64
#  6   price            165873 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 8.9+ MB

# %%
hotel_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108048 entries, 0 to 108047
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            108048 non-null  int64
#  1   hotelid       108048 non-null  int64
#  2   hotelname     108048 non-null  object
#  3   address       102955 non-null  object
#  4   city          108048 non-null  object
#  5   country       108048 non-null  object
#  6   zipcode       83486 non-null   float64
#  7   propertytype  108048 non-null  object
#  8   starrating    108048 non-null  int64
#  9   latitude      108048 non-null  float64
#  10  longitude     108048 non-null  float64
#  11  Source        108048 non-null  int64
#  12  url           107937 non-null  object
#  13  curr          108048 non-null  object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 11.5+ MB

# %%
hotel_details.describe()
# Out:
#                  id       hotelid       zipcode     starrating       latitude  \
# count  108048.00000  1.080480e+05  8.348600e+04  108048.000000  108048.000000
# mean   100429.50000  1.196298e+06  4.814535e+04       3.186537      46.770001
# std     31190.91528  2.096632e+06  9.635945e+04       0.665614       5.438123
# min     46406.00000  3.100000e+01  0.000000e+00       2.000000       0.000000
# 25%     73417.75000  9.402175e+04  9.920000e+03       3.000000      43.309794
# 50%    100429.50000  3.065795e+05  3.430000e+04       3.000000      46.686896
# 75%    127441.25000  1.066211e+06  6.311000e+04       4.000000      50.777548
# max    154453.00000  9.061192e+06  9.545142e+06       4.000000      69.536102
#
#            longitude         Source
# count  108048.000000  108048.000000
# mean        8.345943       3.087461
# std         9.119117       1.442162
# min      -111.908966       2.000000
# 25%         1.442162       2.000000
# 50%         8.975729       2.000000
# 75%        13.661896       5.000000
# max        34.408731       5.000000

# %%
hotel_rooms.describe()
# Out:
#                  id     hotelcode      guests_no          price
# count  1.658730e+05  1.658730e+05  165873.000000  165873.000000
# mean   7.175720e+07  1.170720e+06       3.500642     264.891224
# std    5.508651e+06  2.142096e+06       1.707099     136.189356
# min    5.064343e+07  3.100000e+01       1.000000      30.000000
# 25%    6.983127e+07  8.279800e+04       2.000000     146.000000
# 50%    7.379246e+07  1.559800e+05       4.000000     266.000000
# 75%    7.482301e+07  8.096640e+05       5.000000     382.000000
# max    8.852818e+07  8.977298e+06       6.000000     500.000000

# %% [markdown]
# Data Cleaning and Transformations
#
# We will reduce the data frame by taking only the columns relevent for our work

# %%
del hotel_details['id']
del hotel_rooms['id']
del hotel_details['zipcode']
del hotel_details['latitude']
del hotel_details['longitude']

# %%
hotel_details=hotel_details.dropna()
hotel_rooms=hotel_rooms.dropna()

# %%
hotel_details.drop_duplicates(subset='hotelid', keep=False, inplace=True)

# %% [markdown]
# Merging both data frames based on column

# %%
hotel = pd.merge(hotel_rooms,hotel_details,left_on='hotelcode', right_on='hotelid',how='inner')

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription',
#        'guests_no', 'price', 'hotelid', 'hotelname', 'address', 'city',
#        'country', 'propertytype', 'starrating', 'Source', 'url', 'curr'],
#       dtype='object')

# %%
hotel.shape
# Out:
# (145425, 16)

# %%
del hotel['hotelid']
del hotel['curr']
del hotel['Source']

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription',
#        'guests_no', 'price', 'hotelname', 'address', 'city', 'country',
#        'propertytype', 'starrating', 'url'],
#       dtype='object')

# %% [markdown]
# To ease the process of filtering the hotels we will merge the 2 columns,'roomamenities'&'ratedescription',into a new column description

# %%
hotel['description'] = hotel['roomamenities'] + hotel['ratedescription']

# %%
del hotel['ratedescription']
del hotel['roomamenities']

# %% [markdown]
# Final features of the data frame

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomtype', 'guests_no', 'price', 'hotelname', 'address',
#        'city', 'country', 'propertytype', 'starrating', 'url', 'description'],
#       dtype='object')

# %%
hotel.describe(include='all')
# Out:
#            hotelcode     roomtype      guests_no          price  \
# count   1.454250e+05       145425  145425.000000  145425.000000
# unique           NaN         7743            NaN            NaN
# top              NaN  Double Room            NaN            NaN
# freq             NaN         7566            NaN            NaN
# mean    1.253175e+06          NaN       3.502561     264.837009
# std     2.184205e+06          NaN       1.707571     136.207498
# min     3.100000e+01          NaN       1.000000      30.000000
# 25%     1.080840e+05          NaN       2.000000     146.000000
# 50%     1.666970e+05          NaN       4.000000     266.000000
# 75%     1.013542e+06          NaN       5.000000     382.000000
# max     8.977298e+06          NaN       6.000000     500.000000
#
#                  hotelname      address    city         country propertytype  \
# count               145425       145425  145425          145425       145425
# unique                7951         7877    4116              29            5
# top     Millennium Mayfair  Main Street  London  United Kingdom       Hotels
# freq                   352          407   11387           58886       143932
# mean                   NaN          NaN     NaN             NaN          NaN
# std                    NaN          NaN     NaN             NaN          NaN
# min                    NaN          NaN     NaN             NaN          NaN
# 25%                    NaN          NaN     NaN             NaN          NaN
# 50%                    NaN          NaN     NaN             NaN          NaN
# 75%                    NaN          NaN     NaN             NaN          NaN
# max                    NaN          NaN     NaN             NaN          NaN
#
#            starrating                                                url  \
# count   145425.000000                                             145425
# unique            NaN                                               8098
# top               NaN  https://www.agoda.com/en-gb/millennium-mayfair...
# freq              NaN                                                352
# mean         3.440564                                                NaN
# std          0.622455                                                NaN
# min          2.000000                                                NaN
# 25%          3.000000                                                NaN
# 50%          4.000000                                                NaN
# 75%          4.000000                                                NaN
# max          4.000000                                                NaN
#
#                                               description
# count                                              145425
# unique                                              32333
# top     Air conditioning: ;Free Wi-Fi in all rooms!: ;...
# freq                                                 3485
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# Observations
#
# Hotel Name Millennium Mayfair has the highest frequency of entries
#
# There are 7951 unique hotels
#
# United Kingdom has majority of hotels
#
# Air Conditioning, Free WiFi can be used as top tier room amenities

# %%
sum(hotel.duplicated())
# Out:
# 165

# %% [markdown]
# Check for duplicate values

# %%
sum(hotel.duplicated())
# Out:
# 165

# %% [markdown]
# Below result shows that we have 165 duplicate values

# %%
hotel_after_removing_duplicates= hotel.drop_duplicates()

# %%
sum(hotel_after_removing_duplicates.duplicated())
# Out:
# 0

# %% [markdown]
# Check for missing values

# %%
hotel=hotel_after_removing_duplicates.dropna()

# %%
hotel.describe()
# Out:
#           hotelcode      guests_no          price     starrating
# count  1.452600e+05  145260.000000  145260.000000  145260.000000
# mean   1.253421e+06       3.502527     264.839935       3.440438
# std    2.184356e+06       1.707620     136.204235       0.622505
# min    3.100000e+01       1.000000      30.000000       2.000000
# 25%    1.080885e+05       2.000000     146.000000       3.000000
# 50%    1.667970e+05       4.000000     266.000000       4.000000
# 75%    1.013542e+06       5.000000     382.000000       4.000000
# max    8.977298e+06       6.000000     500.000000       4.000000

# %% [markdown]
# Data Visualization
#
# We did graphs that we think best describes the dataset
#
# Below graph shows the correlation heatmap between the variables

# %%
corr_df=hotel.corr(method="pearson")
pyplot.figure(figsize=(9,6))
heatmap=sns.heatmap(corr_df, annot=True, fmt=".1g", vmin=-1, vmax=1, center=0, cmap="rocket", linewidths=1, linecolor="Black")
heatmap.set_title("Correlation HeatMap bewteen variables")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90);
# Out:
# C:\Users\ANUJ\AppData\Local\Temp\ipykernel_22096\918699477.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df=hotel.corr(method="pearson")

# %%
pyplot.figure(figsize=(15,7))
sns.regplot(data=hotel, y="price", x="starrating", color="r").set(title="Price vs Star Rating Correlation")
# Out:
# [Text(0.5, 1.0, 'Price vs Star Rating Correlation')]

# %% [markdown]
# Showing count of hotels having ratings 2,3 and 4

# %%
plot = hotel[["hotelname","starrating"]].drop_duplicates()
sns.set(font_scale = 1.2)
a4_dims=(11,5)
colors=sns.color_palette("tab10")
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.countplot(ax = ax,x= "starrating", data=plot,palette=colors);

# %% [markdown]
# Top 10 most booked hotels

# %%
Hotel_counts = hotel["hotelname"].value_counts()
Hotel_counts[:10].plot(kind='barh', figsize=(12,6));

# %% [markdown]
# Graph showing count of hotels in each country

# %%
plot = hotel[["city","country"]].drop_duplicates()
plot.groupby('country').count()
sns.set(font_scale = 1.2)
a4_dims=(12,6)
fig, ax=pyplot.subplots(figsize=a4_dims)
pyplot.xticks(rotation=90)
sns.countplot(ax= ax,x = "country",data=plot,palette=colors).set(title="Number of hotels in each country");

# %% [markdown]
# Recommender system based only on City and ratings about the hotel
#
# Adding basic search function that will filter the data frame based on the location the user searches
#
# Base of our filter with be the star ratting for the hotels

# %%
def citybased(city):
  hotel['city']=hotel['city'].str.lower()
  citybase=hotel[hotel['city']==city.lower()]
  citybase=citybase.sort_values(by='starrating',ascending=False)
  citybase.drop_duplicates(subset= 'hotelcode', keep='first', inplace=True)
  if(citybase.empty==0):
    hname=citybase[['hotelname', 'price', 'starrating', 'address', 'description','url']]
    return hname.head(10)
  else:
    print('No Hotels Available')

# %%
hotel_details.head()
hotel_details.loc[:,'city']
# Out:
# 0                Omis
# 1               Torun
# 2             Canazei
# 3             Mykonos
# 4             Lagundo
#              ...
# 108043     Tuttlingen
# 108044     Sveti Vlas
# 108045         Bansko
# 108046    Sunny Beach
# 108047    Sunny Beach
# Name: city, Length: 99154, dtype: object

# %%
citybased('Rome')
# Out:
#                                                 hotelname  price  starrating  \
# 32605                                        Turner Hotel    388           4
# 107510                                American Palace EUR    418           4
# 92966                                      Rome Art Hotel    115           4
# 89813   Hotel Duca d'Alba - Chateaux et Hotels Collection    377           4
# 47874                                 Hotel Pace Helvezia    380           4
# 49149                           Horti 14 Borgo Trastevere    449           4
# 101863                    Bettoja Massimo D'Azeglio Hotel    286           4
# 103737                                   Hotel Metropolis    455           4
# 54189                    Aldrovandi Residence City Suites    141           4
# 34707                                    The Talent Hotel    135           4
#
#                                                   address  \
# 32605                                    Via Nomentana 29
# 107510                                 Via Laurentina 554
# 92966   Via dei Due Macelli 120 - Check in at Trevi Co...
# 89813                                   14 Leonina Street
# 47874                                 Via IV Novembre 104
# 49149                    14 Via di San Francesco di Sales
# 101863                                   18 Cavour Street
# 103737                            26 Delle Milizie Avenue
# 54189                                Via U. Aldrovandi 11
# 34707                                   Via del Corso 287
#
#                                               description  \
# 32605   Additional toilet: ;Air conditioning: ;Alarm c...
# 107510  Air conditioning: ;Cleaning products: ;Closet:...
# 92966   Air conditioning: ;Free Wi-Fi in all rooms!: ;...
# 89813   Air conditioning: ;Closet: ;Daily housekeeping...
# 47874   Air conditioning: ;Carpeting: ;Desk: ;Free Wi-...
# 49149   Air conditioning: ;Alarm clock: ;Bathrobes: ;C...
# 101863  Air conditioning: ;Bathrobes: ;Closet: ;Coffee...
# 103737  Air conditioning: ;Bathrobes: ;Blackout curtai...
# 54189   Air conditioning: ;Carpeting: ;Cleaning produc...
# 34707   Air conditioning: ;Bathrobes: ;Coffee/tea make...
#
#                                                       url
# 32605   https://www.agoda.com/en-gb/turner-hotel/hotel...
# 107510  https://www.agoda.com/en-gb/american-palace-eu...
# 92966   https://www.agoda.com/en-gb/rome-art-hotel_2/h...
# 89813   https://www.agoda.com/en-gb/hotel-duca-d-alba-...
# 47874   https://www.agoda.com/en-gb/hotel-pace-helvezi...
# 49149   https://www.agoda.com/en-gb/horti-14-borgo-tra...
# 101863  https://www.agoda.com/en-gb/bettoja-massimo-d-...
# 103737  https://www.agoda.com/en-gb/hotel-metropolis/h...
# 54189   https://www.agoda.com/en-gb/aldrovandi-residen...
# 34707   https://www.agoda.com/en-gb/the-talent-hotel/h...

# %% [markdown]
# Requirement and special needs based Recommender
#
# As the user might not only search be based on location, so adding a new feature, number of guests

# %%
def pop_citybased(city,number):
  hotel['city']=hotel['city'].str.lower()
  popbased=hotel[hotel['city']==city.lower()]
  popbased=popbased[popbased['guests_no']==number].sort_values(by='starrating', ascending=False)
  popbased.drop_duplicates(subset='hotelcode', keep='first',inplace=True)
  if popbased.empty==True:
    print('Sorry No Hotels Availableln tune your constraints')
  else:
    return popbased[['hotelname','price','roomtype', 'guests_no', 'starrating', 'address', 'description','url']].head(10)

# %%
pop_citybased('rome',4)
# Out:
#                               hotelname  price  \
# 62660               Hotel Degli Artisti    394
# 101847  Bettoja Massimo D'Azeglio Hotel     94
# 103734                 Hotel Metropolis    425
# 47801                         ARS Hotel    318
# 99496           FH Grand Hotel Palatino    266
# 49154         Horti 14 Borgo Trastevere    404
# 32611                      Turner Hotel    196
# 34714                  The Talent Hotel    324
# 107520              American Palace EUR    288
# 46859        Mascagni Luxury Dependance    295
#
#                                            roomtype  guests_no  starrating  \
# 62660                Superior Double Room (1 Adult)          4           4
# 101847                               Double Premium          4           4
# 103734                             Double Executive          4           4
# 47801                                   Triple Room          4           4
# 99496                Standard Triple Room (Classic)          4           4
# 49154   Deluxe Double or Twin Room with Garden View          4           4
# 32611                        Classic Double or Twin          4           4
# 34714                                         Suite          4           4
# 107520                                    Twin Room          4           4
# 46859                     Double Single Use Premium          4           4
#
#                                  address  \
# 62660               Via degli Artisti 18
# 101847                  18 Cavour Street
# 103734           26 Delle Milizie Avenue
# 47801       20/24 Monte Altissimo Street
# 99496                     Via Cavour 213
# 49154   14 Via di San Francesco di Sales
# 32611                   Via Nomentana 29
# 34714                  Via del Corso 287
# 107520                Via Laurentina 554
# 46859      Via Vittorio Emanuele Orlando
#
#                                               description  \
# 62660   Air conditioning: ;Closet: ;Clothes rack: ;Des...
# 101847  Air conditioning: ;Free Wi-Fi in all rooms!: ;...
# 103734  Air conditioning: ;Bathrobes: ;Blackout curtai...
# 47801   Air conditioning: ;Blackout curtains: ;Closet:...
# 99496   Air conditioning: ;Free Wi-Fi in all rooms!: ;...
# 49154   Air conditioning: ;Alarm clock: ;Bathrobes: ;C...
# 32611   Additional toilet: ;Air conditioning: ;Alarm c...
# 34714   Air conditioning: ;Alarm clock: ;Bathrobes: ;C...
# 107520  Air conditioning: ;Cleaning products: ;Closet:...
# 46859   Air conditioning: ;Free Wi-Fi in all rooms!: ;...
#
#                                                       url
# 62660   https://www.agoda.com/en-gb/hotel-degli-artist...
# 101847  https://www.agoda.com/en-gb/bettoja-massimo-d-...
# 103734  https://www.agoda.com/en-gb/hotel-metropolis/h...
# 47801   https://www.agoda.com/en-gb/ars-hotel/hotel/ro...
# 99496   https://www.agoda.com/en-gb/fh-grand-hotel-pal...
# 49154   https://www.agoda.com/en-gb/horti-14-borgo-tra...
# 32611   https://www.agoda.com/en-gb/turner-hotel/hotel...
# 34714   https://www.agoda.com/en-gb/the-talent-hotel/h...
# 107520  https://www.agoda.com/en-gb/american-palace-eu...
# 46859   https://www.agoda.com/en-gb/mascagni-luxury-de...

# %%
hotel.head()
# Out:
#    hotelcode                        roomtype  guests_no  price  \
# 0     634876                     Double Room          6    199
# 1     634876                     Double Room          6    313
# 2     634876  Deluxe Double Room with Shower          4    240
# 3     634876            Superior Double Room          1    242
# 4     634876    Standard Double or Twin Room          5    467
#
#              hotelname           address           city         country  \
# 0  The Old Cider House  25 Castle Street  nether stowey  United Kingdom
# 1  The Old Cider House  25 Castle Street  nether stowey  United Kingdom
# 2  The Old Cider House  25 Castle Street  nether stowey  United Kingdom
# 3  The Old Cider House  25 Castle Street  nether stowey  United Kingdom
# 4  The Old Cider House  25 Castle Street  nether stowey  United Kingdom
#
#   propertytype  starrating                                                url  \
# 0       Hotels           4  https://www.agoda.com/en-gb/the-old-cider-hous...
# 1       Hotels           4  https://www.agoda.com/en-gb/the-old-cider-hous...
# 2       Hotels           4  https://www.agoda.com/en-gb/the-old-cider-hous...
# 3       Hotels           4  https://www.agoda.com/en-gb/the-old-cider-hous...
# 4       Hotels           4  https://www.agoda.com/en-gb/the-old-cider-hous...
#
#                                          description
# 0  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 1  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 2  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 3  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 4  Air conditioning: ;Alarm clock: ;Carpeting: ;C...

# %%
hotel['description']=hotel['description'].str.replace(': ;',',')

# %%
hotel['description']
# Out:
# 0         Air conditioning,Alarm clock,Carpeting,Closet,...
# 1         Air conditioning,Alarm clock,Carpeting,Closet,...
# 2         Air conditioning,Alarm clock,Carpeting,Closet,...
# 3         Air conditioning,Alarm clock,Carpeting,Closet,...
# 4         Air conditioning,Alarm clock,Carpeting,Closet,...
#                                 ...
# 145420    Air conditioning,Dressing room,Free Wi-Fi in a...
# 145421    Air conditioning,Dressing room,Free Wi-Fi in a...
# 145422    Air conditioning,Free Wi-Fi in all rooms!,In-r...
# 145423    Air conditioning,Free Wi-Fi in all rooms!,In-r...
# 145424    Air conditioning,Free Wi-Fi in all rooms!,In-r...
# Name: description, Length: 145260, dtype: object

# %%
def requirementbased(city, number,features):
  hotel['city']=hotel['city'].str.lower()
  hotel['description']=hotel['description'].str.lower()
  features=features.lower()
  features_tokens=word_tokenize(features)
  sw =stopwords.words('english')
  lemm=WordNetLemmatizer()
  f1_set={w for w in features_tokens if not w in sw}
  f_set=set()
  for se in f1_set:
    f_set.add(lemm.lemmatize(se))
  reqbased=hotel[hotel['city']==city.lower()]
  reqbased=reqbased[reqbased['guests_no']==number].sort_values(by='starrating',ascending=False)
  reqbased=reqbased.set_index(np.arange(reqbased.shape[0]))
  cos=[];

  for i in range(reqbased.shape[0]):
    temp_tokens=word_tokenize(reqbased['description'][i])
    templ_set={w for w in temp_tokens if not w in sw}
    temp_set=set()
    for se in templ_set:
      temp_set.add(lemm.lemmatize(se))
    rvector=temp_set.intersection(f_set)
    #print(rvector)
    cos.append(len(rvector))
  reqbased['similarity']=cos
  reqbased=reqbased.sort_values(by='similarity',ascending=False)
  reqbased.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
  return reqbased[['hotelname', 'roomtype', 'price', 'guests_no', 'starrating','address','description','similarity','url']].head(10)

# %%
requirementbased('london', 4, 'I need wifi')
# Out:
#                                               hotelname  \
# 0                                 The Royal Chace Hotel
# 1330                         Brook Kingston Lodge Hotel
# 1342              Holiday Inn London - Heathrow M4Jct.4
# 1341                     Crowne Plaza London - The City
# 1340                              Corus Hotel Hyde Park
# 1314           Hotel Indigo London - 1 Leicester Square
# 1328                                Sloane Square Hotel
# 1326                         Grange Langham Court Hotel
# 1323  Clarion Collection Harte and Garter Hotel and Spa
# 1321                                Grange Blooms Hotel
#
#                         roomtype  price  guests_no  starrating  \
# 0                    Double Room    468          4           4
# 1330             Executive Suite    233          4           4
# 1342       Executive Double Room    225          4           4
# 1341             Studio King bed    388          4           4
# 1340              Executive Twin    158          4           4
# 1314       Superior Premium Room     73          4           4
# 1328                    Superior    235          4           4
# 1326  Double Single Use Superior    435          4           4
# 1323       Standard 1 Double bed    434          4           4
# 1321        Superior Double Room    266          4           4
#
#                                                 address  \
# 0                                      162 The Ridgeway
# 1330  94 Kingston Hill, Kingston Upon Thames, Surrey...
# 1342                                        Sipson Road
# 1341                               19 New Bridge Street
# 1340                                 1-7 Lancaster Gate
# 1314                                 1 Leicester Square
# 1328                                      Sloane Square
# 1326                               31-35 Langham Street
# 1323                                     31 High Street
# 1321                                  7 Montague Street
#
#                                             description  similarity  \
# 0     additional toilet,air conditioning,carpeting,c...           0
# 1330  air conditioning,carpeting,cleaning products,c...           0
# 1342  air conditioning,bathrobes,blackout curtains,c...           0
# 1341  air conditioning,bathrobes,carpeting,closet,co...           0
# 1340  air conditioning,alarm clock,closet,clothes ra...           0
# 1314  air conditioning,alarm clock,bathrobes,carpeti...           0
# 1328  air conditioning,alarm clock,bathrobes,blackou...           0
# 1326  air conditioning,closet,free wi-fi in all room...           0
# 1323  air conditioning,blackout curtains,closet,coff...           0
# 1321  air conditioning,closet,coffee/tea maker,daily...           0
#
#                                                     url
# 0     https://www.agoda.com/en-gb/the-royal-chace-ho...
# 1330  https://www.agoda.com/en-gb/brook-kingston-lod...
# 1342  https://www.agoda.com/en-gb/holiday-inn-london...
# 1341  https://www.agoda.com/en-gb/crowne-plaza-londo...
# 1340  https://www.agoda.com/en-gb/corus-hotel-hyde-p...
# 1314  https://www.agoda.com/en-gb/hotel-indigo-londo...
# 1328  https://www.agoda.com/en-gb/sloane-square-hote...
# 1326  https://www.agoda.com/en-gb/grange-langham-cou...
# 1323  https://www.agoda.com/en-gb/clarion-collection...
# 1321  https://www.agoda.com/en-gb/grange-blooms-hote...

# %%
def recommender(city, number,features,price):
    hotel['city']=hotel['city'].str.lower()
    hotel['description']=hotel['description'].str.lower()
    features=features.lower()
    features_tokens=word_tokenize(features)
    sw = stopwords.words('english')
    lemm = WordNetLemmatizer()
    f1_set= {w for w in features_tokens if not w in sw}
    f_set=set()
    for se in f1_set:
        f_set.add(lemm.lemmatize(se))
    reqbased=hotel[hotel['city']==city.lower()]
    reqbased=reqbased[reqbased['guests_no']==number]
    reqbased=reqbased[reqbased['price'] <= price].sort_values(by='starrating', ascending=False)
    reqbased=reqbased.set_index(np.arange(reqbased.shape[0]))
    cos=[];

    #print(reqbased['roomamenities'])
    for i in range(reqbased.shape[0]):
      temp_tokens=word_tokenize(reqbased['description'][i])
      temp1_set={w for w in temp_tokens if not w in sw}
      temp_set=set()
      for se in temp1_set:
        temp_set.add(lemm.lemmatize(se))
      rvector = temp_set.intersection(f_set)
      #print (rvector)
      cos.append(len(rvector))
    reqbased['similarity']=cos
    reqbased=reqbased.sort_values(by='similarity', ascending=False)
    reqbased.drop_duplicates(subset='hotelcode', keep='first',inplace=True)
    return reqbased[['hotelname','roomtype','price','guests_no','starrating','address','description','similarity','url']].head(10)

# %%
recommender('London', 2, 'I need free wifi and breakfast',75)
# Out:
#                                              hotelname  \
# 141               Comfort Inn St Pancras - Kings Cross
# 64                          The Colonnade London Hotel
# 86   100 Queen's Gate Hotel London, Curio Collectio...
# 78                                   The Cranley Hotel
# 173                                   OYO Anchor Hotel
# 128           City Continental London Kensington Hotel
# 122                                Grange Blooms Hotel
# 123                                  Bridge Park Hotel
# 125                Holiday Inn London - Heathrow Ariel
# 126             Best Western Plus London Wembley Hotel
#
#                        roomtype  price  guests_no  starrating  \
# 141         Suite - Non-Smoking     70          2           3
# 64                     Standard     55          2           4
# 86            King Duplex Suite     44          2           4
# 78                 Junior Suite     61          2           4
# 173               Twin Standard     48          2           3
# 128                 Double Room     54          2           3
# 122       Executive Double Room     31          2           4
# 123          Superior King Room     64          2           3
# 125    1 Double Bed Non-Smoking     61          2           3
# 126  Standard Double No Window      46          2           3
#
#                                         address  \
# 141                       2-5 St. Chad's Street
# 64                        2 Warrington Crescent
# 86                             100 Queen's Gate
# 78            10 Bina Gardens, South Kensington
# 173  10 West Heath Drive, Golders Green, London
# 128                         11-13 Penywern Road
# 122                           7 Montague Street
# 123                                16 Hillside,
# 125                               118 Bath Road
# 126                      365 High Road, Wembley
#
#                                            description  similarity  \
# 141  air conditioning,free wi-fi in all rooms!,in-r...           2
# 64   air conditioning,free wi-fi in all rooms!,in-r...           2
# 86   air conditioning,coffee/tea maker,free wi-fi i...           2
# 78   air conditioning,daily housekeeping,daily news...           2
# 173  air conditioning,free wi-fi in all rooms!,in-r...           2
# 128  air conditioning,closet,clothes rack,coffee/te...           1
# 122  air conditioning,closet,coffee/tea maker,daily...           1
# 123  air conditioning,free wi-fi in all rooms!,in-r...           1
# 125  additional toilet,air conditioning,carpeting,c...           1
# 126  air conditioning,blackout curtains,coffee/tea ...           1
#
#                                                    url
# 141  https://www.agoda.com/en-gb/comfort-inn-st-pan...
# 64   https://www.agoda.com/en-gb/the-colonnade-lond...
# 86   https://www.agoda.com/en-gb/100-queen-s-gate-h...
# 78   https://www.agoda.com/en-gb/the-cranley-hotel/...
# 173  https://www.agoda.com/en-gb/anchor-house/hotel...
# 128  https://www.agoda.com/en-gb/city-continental-l...
# 122  https://www.agoda.com/en-gb/grange-blooms-hote...
# 123  https://www.agoda.com/en-gb/bridge-park-hotel/...
# 125  https://www.agoda.com/en-gb/holiday-inn-london...
# 126  https://www.agoda.com/en-gb/best-western-plus-...
